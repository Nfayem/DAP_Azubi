# %% [markdown]
# # CEASAR'S CIPHER PROJECT

# %% [markdown]
# ### Author(s): Nfayem Imoro

# %% [markdown]
# The programme uses a ceasar or shift cipher, a type of substitution cipher, to encrypt and decrypt messages. It prompts the user to choose between encryption and decryption modes and then prompts the user to enter a key and the text to be encrypted or decrypted. Finally, it prints the result.

# %% [markdown]
# For example:

# %% [markdown]
# Plaintext = THE QUICK BROWN FOX JUMPS OVER THE LAZY DOG

# %% [markdown]
# Ciphertext = QEB NRFZH YOLTK CLU GRJMP LSBO QEB IXWV ALD

# %% [markdown]
# ### TIER 1

# %% [markdown]
# #### Left Shift Cipher

# %%
letters = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
num_letters = len(letters)

# Function to encrypt or decrypt a given text using a Caesar cipher
def encrypt_decrypt (text, mode, key):
    changed_text = ""
    if mode == "d":
        key = -key
    for letter in text:
        letter = letter.upper()
        if letter == " ":
            changed_text += letter
        if not letter == " ":
            index = letters.find(letter)
            if index == -1:
                changed_text += letter
            else:
                new_index = index - key
                if new_index < 0:
                    new_index += num_letters
                elif new_index >= num_letters:
                    new_index -= num_letters
                changed_text += letters[new_index]
    return changed_text

# Print program title
print()
print("***CEASAR CIPHER PROGRAM***")
print()

# Prompt the user to choose encryption or decryption mode

print("Do you want to encrypt or decrypt?")
# Check if mode input is either e for encryption or d for decryption
while True:
    try:
        mode = input("Please enter either 'e' for encryption or 'd' for decryption:").lower()
        if mode not in ["e", "d"]:
            raise ValueError
        break
    except ValueError:
        print("Invalid input. Please enter a valid text from this list: ['e', 'd']")   
       
print()

# Based on the chosen mode, perform encryption or decryption

if mode == "e":
    print("ENCRYPTION MODE SELECTED")
    print()
    
    # Validate key input
    while True:
        try:
            key = int(input("Please enter a key between 1 and 25:"))
            if key < 1 or key > 25:
                print("Please enter a positive integer between 1 and 25")
            else:
                break
        except ValueError:
            print("Invalid input. Please enter a valid integer value")

    # Check if text input is empty
    text = input("Please enter the text to be encrypted:")
    while text == " ":
        print("Error: Input cannot be empty")
        text = input("Please enter the text to be encrypted:")
        
    # Encrypt the text using the specified key and print the encrypted text
    ciphertext = encrypt_decrypt(text, mode, key)
    print(f"CIPHERTEXT: {ciphertext}")
 
elif mode == "d":
    print("DECRYPTION MODE SELECTED")
    print()
    
    # Validate key input
    while True:
        try:
            key = int(input("Please enter a key between 1 and 25:"))
            if key < 1 or key > 25:
                print("Please enter a positive integer between 1 and 25")
            else:
                break
        except ValueError:
            print("Invalid input. Please enter a valid integer value")

    # Check if text input is empty
    text = input("Please enter the text to be decrypted:")
    while text == " ":
        print("Error: Input cannot be empty")
        text = input("Please enter the text to be decrypted:")
    
    # Decrypt the text using the specified key and print the decrypted text.
    plaintext = encrypt_decrypt(text, mode, key)
    print(f"PLAINTEXT: {plaintext}")

# %% [markdown]
# #### Right Shift Cipher

# %%
letters = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
num_letters = len(letters)

# Function to encrypt or decrypt a given text using a Caesar cipher
def encrypt_decrypt (text, mode, key):
    changed_text = ""
    if mode == "d":
        key = -key
    for letter in text:
        letter = letter.upper()
        if letter == " ":
            changed_text += letter
        if not letter == " ":
            index = letters.find(letter)
            if index == -1:
                changed_text += letter
            else:
                new_index = index + key
                if new_index >= num_letters:
                    new_index -= num_letters
                elif new_index < 0:
                    new_index += num_letters
                changed_text += letters[new_index]
    return changed_text

# Print program title
print()
print("***CEASAR CIPHER PROGRAM***")
print()

# Check if mode input is either e for encryption or d for decryption
print("Do you want to encrypt or decrypt?")
# Check if mode input is either e for encryption or d for decryption
while True:
    try:
        mode = input("Please enter either 'e' for encryption or 'd' for decryption:").lower()
        if mode not in ["e", "d"]:
            raise ValueError
        break
    except ValueError:
        print("Invalid input. Please enter a valid text from this list: ['e', 'd']")   
       
print()

# Based on the chosen mode, perform encryption or decryption

if mode == "e":
    print("ENCRYPTION MODE SELECTED")
    print()
    
    # Validate key input
    while True:
        try:
            key = int(input("Please enter a key between 1 and 25:"))
            if key < 1 or key > 25:
                print("Please enter a positive integer between 1 and 25")
            else:
                break
        except ValueError:
            print("Invalid input. Please enter a valid integer value")

    # Check if text input is empty
    text = input("Please enter the text to be encrypted:")
    while text == " ":
        print("Error: Input cannot be empty")
        text = input("Please enter the text to be encrypted:")
    
    # Encrypt the text using the specified key and print the encrypted text
    ciphertext = encrypt_decrypt(text, mode, key)
    print(f"CIPHERTEXT: {ciphertext}")
 
elif mode == "d":
    print("DECRYPTION MODE SELECTED")
    print()
    
    # Validate key input
    while True:
        try:
            key = int(input("Please enter a key between 1 and 25:"))
            if key < 1 or key > 25:
                print("Please enter a positive integer between 1 and 25")
            else:
                break
        except ValueError:
            print("Invalid input. Please enter a valid integer value")

    # Check if text input is empty
    text = input("Please enter the text to be decrypted:")
    while text == " ":
        print("Error: Input cannot be empty")
        text = input("Please enter the text to be decrypted:")
    
    # Decrypt the text using the specified key and print the decrypted text.
    plaintext = encrypt_decrypt(text, mode, key)
    print(f"PLAINTEXT: {plaintext}")

# %% [markdown]
# ### TIER 2

# %% [markdown]
# #### Left Shift Cipher

# %%
letters = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
num_letters = len(letters)

def encrypt (plaintext, key):
    ciphertext = ""
    for letter in plaintext:
        letter = letter.upper()
        if letter == " ":
            ciphertext += letter
        if not letter == " ":
            index = letters.find(letter)
            if index == -1:
                ciphertext += letter
            else:
                new_index = index - key
                if new_index < 0:
                    new_index += num_letters
                ciphertext += letters[new_index]
    return ciphertext

def decrypt (ciphertext, key):
    plaintext = ""
    for letter in ciphertext:
        letter = letter.upper()
        if letter == " ":
            plaintext += letter
        if not letter == " ":
            index = letters.find(letter)
            if index == -1:
                plaintext += letter
            else:
                new_index = index + key
                if new_index >= 26:
                    new_index -= num_letters
                plaintext += letters[new_index]
    return plaintext                       
        
print()
print("***CEASAR CIPHER PROGRAM***")
print()

print("Do you want to encrypt or decrypt?")

# Check if mode input is either e for encryption or d for decryption
while True:
    try:
        mode = input("Please enter either 'e' for encryption or 'd' for decryption:").lower()
        if mode not in ["e", "d"]:
            raise ValueError
        break
    except ValueError:
        print("Invalid input. Please enter a valid text from this list: ['e', 'd']")   
       
print()

if mode == "e":
    print("ENCRYPTION MODE SELECTED")
    print()
    
    # Validate key input
    while True:
        try:
            key = int(input("Please enter a key between 1 and 25:"))
            if key < 1 or key > 25:
                print("Please enter a positive integer between 1 and 25")
            else:
                break
        except ValueError:
            print("Invalid input. Please enter a valid integer value")

    # Check if text input is empty
    text = input("Please enter the text to be encrypted:")
    while text == " ":
        print("Error: Input cannot be empty")
        text = input("Please enter the text to be encrypted:")
    ciphertext = encrypt(text, key)
    print(f"CIPHERTEXT: {ciphertext}")
 
elif mode == "d":
    print("DECRYPTION MODE SELECTED")
    print()
    
    # Validate key input
    while True:
        try:
            key = int(input("Please enter a key between 1 and 25:"))
            if key < 1 or key > 25:
                print("Please enter a positive integer between 1 and 25")
            else:
                break
        except ValueError:
            print("Invalid input. Please enter a valid integer value")

    # Check if text input is empty
    text = input("Please enter the text to be decrypted:")
    while text == " ":
        print("Error: Input cannot be empty")
        text = input("Please enter the text to be decrypted:")
    plaintext = decrypt(text, key)
    print(f"PLAINTEXT: {plaintext}")

# %% [markdown]
# #### Right Shift Cipher

# %%
letters = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
num_letters = len(letters)

def encrypt (plaintext, key):
    ciphertext = ""
    for letter in plaintext:
        letter = letter.upper()
        if letter == " ":
            ciphertext += letter
        if not letter == " ":
            index = letters.find(letter)
            if index == -1:
                ciphertext += letter
            else:
                new_index = index + key
                if new_index >= 26:
                    new_index -= num_letters
                ciphertext += letters[new_index]
    return ciphertext

def decrypt (ciphertext, key):
    plaintext = ""
    for letter in ciphertext:
        letter = letter.upper()
        if letter == " ":
            plaintext += letter
        if not letter == " ":
            index = letters.find(letter)
            if index == -1:
                plaintext += letter
            else:
                new_index = index - key
                if new_index < 0:
                    new_index += num_letters
                plaintext += letters[new_index]
    return plaintext                       
        
print()
print("***CEASAR CIPHER PROGRAM***")
print()

print("Do you want to encrypt or decrypt?")

# Check if mode input is either e for encryption or d for decryption
while True:
    try:
        mode = input("Please enter either 'e' for encryption or 'd' for decryption:").lower()
        if mode not in ["e", "d"]:
            raise ValueError
        break
    except ValueError:
        print("Invalid input. Please enter a valid text from this list: ['e', 'd']")   
       
print()

if mode == "e":
    print("ENCRYPTION MODE SELECTED")
    print()
    
    # Validate key input
    while True:
        try:
            key = int(input("Please enter a key between 1 and 25:"))
            if key < 1 or key > 25:
                print("Please enter a positive integer between 1 and 25")
            else:
                break
        except ValueError:
            print("Invalid input. Please enter a valid integer value")

    # Check if text input is empty
    text = input("Please enter the text to be encrypted:")
    while text == " ":
        print("Error: Input cannot be empty")
        text = input("Please enter the text to be encrypted:")
    ciphertext = encrypt(text, key)
    print(f"CIPHERTEXT: {ciphertext}")
 
elif mode == "d":
    print("DECRYPTION MODE SELECTED")
    print()
    
    # Validate key input
    while True:
        try:
            key = int(input("Please enter a key between 1 and 25:"))
            if key < 1 or key > 25:
                print("Please enter a positive integer between 1 and 25")
            else:
                break
        except ValueError:
            print("Invalid input. Please enter a valid integer value")

    # Check if text input is empty
    text = input("Please enter the text to be decrypted:")
    while text == " ":
        print("Error: Input cannot be empty")
        text = input("Please enter the text to be decrypted:")
    plaintext = decrypt(text, key)
    print(f"PLAINTEXT: {plaintext}")

# %% [markdown]
# ### TIER 3

# %% [markdown]
# #### Left Shift Cipher

# %%
letters = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
num_letters = len(letters)

def encrypt_decrypt (text, mode, key):
    changed_text = ""
    if mode == "d":
        key = -key
    for letter in text:
        letter = letter.upper()
        if letter == " ":
            changed_text += letter
        if not letter == " ":
            index = letters.find(letter)
            if index == -1:
                changed_text += letter
            else:
                new_index = index - key
                if new_index < 0:
                    new_index += num_letters
                elif new_index >= num_letters:
                    new_index -= num_letters
                changed_text += letters[new_index]
    return changed_text

print()
print("***CEASAR CIPHER PROGRAM***")
print()

print("Do you want to encrypt or decrypt?")
mode = input("Please enter either 'e' for encryption or 'd' for decryption:").lower()
print()

if mode == "e":
    print("ENCRYPTION MODE SELECTED")
    print()
    key = int(input("Please enter a key between 1 and 25:"))
    text = input("Please enter the text to be encrypted:")
    ciphertext = encrypt_decrypt(text, mode, key)
    print(f"CIPHERTEXT: {ciphertext}")

elif mode == "d":
    print("DECRYPTION MODE SELECTED")
    print()
    key = int(input("Please enter a key between 1 and 25:"))
    text = input("Please enter the text to be decrypted:")
    plaintext = encrypt_decrypt(text, mode, key)
    print(f"PLAINTEXT: {plaintext}")

# %% [markdown]
# #### Right Shift Cipher

# %%
letters = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
num_letters = len(letters)

def encrypt_decrypt (text, mode, key):
    changed_text = ""
    if mode == "d":
        key = -key
    for letter in text:
        letter = letter.upper()
        if letter == " ":
            changed_text += letter
        if not letter == " ":
            index = letters.find(letter)
            if index == -1:
                changed_text += letter
            else:
                new_index = index + key
                if new_index >= num_letters:
                    new_index -= num_letters
                elif new_index < 0:
                    new_index += num_letters
                changed_text += letters[new_index]
    return changed_text

print()
print("***CEASAR CIPHER PROGRAM***")
print()

print("Do you want to encrypt or decrypt?")
mode = input("Please enter either 'e' for encryption or 'd' for decryption:").lower()
print()

if mode == "e":
    print("ENCRYPTION MODE SELECTED")
    print()
    key = int(input("Please enter a key between 1 and 25:"))
    text = input("Please enter the text to be encrypted:")
    ciphertext = encrypt_decrypt(text, mode, key)
    print(f"CIPHERTEXT: {ciphertext}")

elif mode == "d":
    print("DECRYPTION MODE SELECTED")
    print()
    key = int(input("Please enter a key between 1 and 25:"))
    text = input("Please enter the text to be decrypted:")
    plaintext = encrypt_decrypt(text, mode, key)
    print(f"PLAINTEXT: {plaintext}")

# %% [markdown]
# ### TIER 4

# %% [markdown]
# #### Left Shift Cipher

# %%
letters = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
num_letters = len(letters)

def encrypt (plaintext, key):
    ciphertext = ""
    for letter in plaintext:
        letter = letter.upper()
        if letter == " ":
            ciphertext += letter
        if not letter == " ":
            index = letters.find(letter)
            if index == -1:
                ciphertext += letter
            else:
                new_index = index - key
                if new_index < 0:
                    new_index += num_letters
                ciphertext += letters[new_index]
    return ciphertext

def decrypt (ciphertext, key):
    plaintext = ""
    for letter in ciphertext:
        letter = letter.upper()
        if letter == " ":
            plaintext += letter
        if not letter == " ":
            index = letters.find(letter)
            if index == -1:
                plaintext += letter
            else:
                new_index = index + key
                if new_index >= 26:
                    new_index -= num_letters
                plaintext += letters[new_index]
    return plaintext

print()
print("***CEASAR CIPHER PROGRAM***")
print()

print("Do you want to encrypt or decrypt?")
mode = input("Please enter either 'e' for encryption or 'd' for decryption:").lower()
print()

if mode == "e":
    print("ENCRYPTION MODE SELECTED")
    print()
    key = int(input("Please enter a key between 1 and 25:"))
    text = input("Please enter the text to be encrypted:")
    ciphertext = encrypt(text, key)
    print(f"CIPHERTEXT: {ciphertext}")

elif mode == "d":
    print("DECRYPTION MODE SELECTED")
    print()
    key = int(input("Please enter a key between 1 and 25:"))
    text = input("Please enter the text to be decrypted:")
    plaintext = decrypt(text, key)
    print(f"PLAINTEXT: {plaintext}")

# %% [markdown]
# #### Right Shift Cipher

# %%
letters = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
num_letters = len(letters)

def encrypt (plaintext, key):
    ciphertext = ""
    for letter in plaintext:
        letter = letter.upper()
        if letter == " ":
            ciphertext += letter
        if not letter == " ":
            index = letters.find(letter)
            if index == -1:
                ciphertext += letter
            else:
                new_index = index + key
                if new_index >= 26:
                    new_index -= num_letters
                ciphertext += letters[new_index]
    return ciphertext

def decrypt (ciphertext, key):
    plaintext = ""
    for letter in ciphertext:
        letter = letter.upper()
        if letter == " ":
            plaintext += letter
        if not letter == " ":
            index = letters.find(letter)
            if index == -1:
                plaintext += letter
            else:
                new_index = index - key
                if new_index < 0:
                    new_index += num_letters
                plaintext += letters[new_index]
    return plaintext

print()
print("***CEASAR CIPHER PROGRAM***")
print()

print("Do you want to encrypt or decrypt?")
mode = input("Please enter either 'e' for encryption or 'd' for decryption:").lower()
print()

if mode == "e":
    print("ENCRYPTION MODE SELECTED")
    print()
    key = int(input("Please enter a key between 1 and 25:"))
    text = input("Please enter the text to be encrypted:")
    ciphertext = encrypt(text, key)
    print(f"CIPHERTEXT: {ciphertext}")

elif mode == "d":
    print("DECRYPTION MODE SELECTED")
    print()
    key = int(input("Please enter a key between 1 and 25:"))
    text = input("Please enter the text to be decrypted:")
    plaintext = decrypt(text, key)
    print(f"PLAINTEXT: {plaintext}")
